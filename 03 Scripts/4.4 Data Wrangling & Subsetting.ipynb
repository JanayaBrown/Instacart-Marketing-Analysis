# %% [markdown]
# # 0. Contents

# %% [markdown]
# 1. depermentment_id dataframe

# %% [markdown]
# 2. Data wrangling for the orders dataframe

# %% [markdown]
# 3. Creating the snacks dataframe

# %% [markdown]
# 4. Creating the busiest ordering hours column

# %% [markdown]
# 5. Creating the party dataframe

# %% [markdown]
# 6. Creating the dinner dataframe

# %% [markdown]
# # 1. Importing Data

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %%
# creating main path
path = r'C:\Users\muffi\OneDrive\CareerFoundry\Instacart Basket Analysis 2023'

# %%
# importing orders dataframe
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# checking the dataframe
#df_ords.head()

# %%
# importing products dataframe
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# checking the dataframe
#df_prods.head()

# %%
# importing departments dataframe
df_deps = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# checking the dataframe
#df_deps.head()

# %% [markdown]
# # 2. Data Wrangling

# %%
# .drop(columns = ['col_name']) drops a col
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# df['variable'].value_counts(dropna = False) 
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# .rename(columns - {'old name' : 'new_name'}, inplace = True) renames cols
# inplace = True overwrites the original col
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# checking the table
#df_ords.head()

# %%
# changing a col data type using .astype()
df_ords['order_id'] = df_ords['order_id'].astype('str')

# checking the data type
#df_ords['order_id'].dtype

# %%
# .T transposes a dataframe
df_deps_t = df_deps.T

# %%
# viewing the transposed dataframe
df_deps_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# .reset_index() adds an index
df_deps_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# copying the first row
new_header = df_deps_t.iloc[0]

# %%
# viewing the new header
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# creatin a new table without the incorrect header row
df_deps_t_new = df_deps_t[1:]

# %%
df_deps_t_new.columns = new_header

# %% [markdown]
# # 3. Data Dictionaries

# %%
# creating a data dictionary
data_dict = df_deps_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# using a data dictionary
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # 4. Subsetting

# %%
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# .loc[] looks for col names 
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# .isin([]) looks for a multiple cols
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %% [markdown]
# # 5. Exporting Dataframes

# %%
df_ords.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# exporting dataframes
#df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# # 6. Exercise Activities

# %% [markdown]
# ## 6.1. Changing df_ords Identification Columns

# %%
# checking the order dataframe data types
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 156.6+ MB

# %%
# changing user_into a string
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# checking the the new data type
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## 6.2. Changing Intuitive Column Names

# %%
df_ords.rename(columns = {'order_id' : 'orders_identification_number'}, inplace = False)
# Out:
#         orders_identification_number user_id  order_number  \
# 0                            2539329       1             1
# 1                            2398795       1             2
# 2                             473747       1             3
# 3                            2254736       1             4
# 4                             431534       1             5
# ...                              ...     ...           ...
# 3421078                      2266710  206209            10
# 3421079                      1854736  206209            11
# 3421080                       626363  206209            12
# 3421081                      2977660  206209            13
# 3421082                       272231  206209            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %% [markdown]
# ## 6.3. Busiest Ordering Hous

# %%
# in orders table
# need the order_hour_of_day col
# need col counts
# don't drop anything
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
# 10:00 AM is the most popular time to place an order (288,418 orders were placed during this hour).

# %% [markdown]
# ## 6.4. Meaning of department_id 4

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# department 4 is produce

# %% [markdown]
# ## 6.5. Breakfast Subset

# %%
# department 14 is breakfast
# find the location of the rows where the department id is 14
# choose the rows where the department id is 14 and assign to new dataframe
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
# checking the dataframe
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# ## 6.6. Dinner Paty Subset

# %%
# needs to contain the alcohol-5, deli-20, beverages-7, and meat/seafood-12 departments
df_dinner = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
#checking the dataframe
df_dinner.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %% [markdown]
# ## 6.7. Dinner Party Dataframe Dimensions

# %%
# getting the dimensions for the dinner party dataframe
df_dinner.shape
# Out:
# (7650, 5)

# %%
# The dinner party dataframe as 7650 rows.

# %% [markdown]
# ## 6.8. User 1 Data

# %%
# need the orders dataframe
# need to locate the rows where the user_id is 1
# need to linit to only those rows and assign it to a new dataframe
df_user_1 = df_ords.loc[df_ords['user_id'] == '1']

# %%
# checking the new dataframe
df_user_1.head(20)
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# ## 6.9. User 1 Details

# %%
# gathering descriptive statistics about user 1
df_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# There are 11 orders from user 1.
# On average, user 1 orders around the 2nd or 3rd day of the week.
# On average, user 1 waits 10 dats inbetween orders.
# On average, user 1 orders at 10 am.
# The earliest user has ordered is 7 am.
# The lastest user 1 makes orders is 4 pm.
# There is an issue with one of user 1's orders (order 2539329 is missing it's data for the days since prior order).

# %% [markdown]
# ## 6.10. Exporting Wrangled Data

# %%
# exporting orders wrangled dataframes
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled3.csv'))

# %%
# exporting departments wrangled dataframes
df_deps_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 156.6+ MB
